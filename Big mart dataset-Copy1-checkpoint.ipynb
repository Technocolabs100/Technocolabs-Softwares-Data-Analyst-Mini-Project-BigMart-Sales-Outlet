# %%
# Load CSV
import numpy
import pandas as pd
filename = 'train.csv'
data=pd.read_csv(filename)
print(data.shape)
import seaborn as sns
# Out:
# (8523, 12)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
data.nunique()    # how much unique values are there in our data
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
# acess the unique value
data['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
data.isnull().sum()   #to check how many null values are there
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# how to fill null values

# %%
data['Item_Weight'].unique()
# Out:
# array([ 9.3  ,  5.92 , 17.5  , 19.2  ,  8.93 , 10.395, 13.65 ,    nan,
#        16.2  , 11.8  , 18.5  , 15.1  , 17.6  , 16.35 ,  9.   , 13.35 ,
#        18.85 , 14.6  , 13.85 , 13.   ,  7.645, 11.65 ,  5.925, 19.25 ,
#        18.6  , 18.7  , 17.85 , 10.   ,  8.85 ,  9.8  , 13.6  , 21.35 ,
#        12.15 ,  6.42 , 19.6  , 15.85 ,  7.39 , 10.195,  9.895, 10.895,
#         7.905,  9.195,  8.365,  7.97 , 17.7  , 19.35 ,  8.645, 15.6  ,
#        18.25 ,  7.855,  7.825,  8.39 , 12.85 , 19.   ,  5.905,  7.76 ,
#        16.75 , 15.5  ,  6.055,  6.305, 20.85 , 20.75 ,  8.895, 19.7  ,
#         8.75 , 13.3  ,  8.31 , 19.75 , 17.1  , 10.5  ,  6.635, 14.15 ,
#         8.89 ,  9.1  ,  7.5  , 16.85 ,  7.485, 11.6  , 12.65 , 20.25 ,
#         8.6  , 12.6  ,  8.88 , 20.5  , 13.5  ,  7.235,  6.92 ,  8.02 ,
#        12.8  , 16.6  , 14.   , 16.   , 21.25 ,  7.365, 18.35 ,  5.465,
#         7.27 ,  6.155, 19.5  , 15.2  , 14.5  , 13.1  , 12.3  , 11.1  ,
# ...

# %%
data['Item_Weight'].value_counts()
# Out:
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
#           ..
# 7.275      2
# 7.685      1
# 9.420      1
# 6.520      1
# 5.400      1
# Name: Item_Weight, Length: 415, dtype: int64

# %%
# Replace the missing values with mode
data['Item_Weight'].mode()[0]
# Out:
# 12.15

# %%
data['Item_Weight']=data['Item_Weight'].fillna(data['Item_Weight'].mode()[0])

# %%
#df=pd.show(data['Item_Type'])

# %%
# how to transpose a dataset or dataframe

# %%
data['Item_Weight'].isnull().sum()
# Out:
# 0

# %%
data['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
data['Outlet_Size'].isnull().sum()
# Out:
# 2410

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
# Replace the missing values with mode
data['Outlet_Size'].mode()[0]
# Out:
# 'Medium'

# %%
data['Outlet_Size']=data['Outlet_Size'].fillna(data['Outlet_Size'].mode()[0])

# %%
data['Outlet_Size'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
x=data[['Item_Type','Item_Weight']]

# %%
x
# Out:
#                   Item_Type  Item_Weight
# 0                     Dairy        9.300
# 1               Soft Drinks        5.920
# 2                      Meat       17.500
# 3     Fruits and Vegetables       19.200
# 4                 Household        8.930
# ...                     ...          ...
# 8518            Snack Foods        6.865
# 8519           Baking Goods        8.380
# 8520     Health and Hygiene       10.600
# 8521            Snack Foods        7.210
# 8522            Soft Drinks       14.800
#
# [8523 rows x 2 columns]

# %%
x.head()
# Out:
#                Item_Type  Item_Weight
# 0                  Dairy         9.30
# 1            Soft Drinks         5.92
# 2                   Meat        17.50
# 3  Fruits and Vegetables        19.20
# 4              Household         8.93

# %%
df=pd.DataFrame(x)

# %%
df
# Out:
#                   Item_Type  Item_Weight
# 0                     Dairy        9.300
# 1               Soft Drinks        5.920
# 2                      Meat       17.500
# 3     Fruits and Vegetables       19.200
# 4                 Household        8.930
# ...                     ...          ...
# 8518            Snack Foods        6.865
# 8519           Baking Goods        8.380
# 8520     Health and Hygiene       10.600
# 8521            Snack Foods        7.210
# 8522            Soft Drinks       14.800
#
# [8523 rows x 2 columns]

# %%
df.sort_values("Item_Type")   # how to sort values in dataframe
# Out:
#           Item_Type  Item_Weight
# 4261   Baking Goods        12.30
# 5387   Baking Goods        20.85
# 5363   Baking Goods        14.00
# 5362   Baking Goods        17.75
# 5354   Baking Goods        12.15
# ...             ...          ...
# 7353  Starchy Foods        16.70
# 7363  Starchy Foods        17.60
# 136   Starchy Foods        12.15
# 6723  Starchy Foods        12.80
# 5237  Starchy Foods        16.00
#
# [8523 rows x 2 columns]

# %%
new_data=df.T

# %%
new_data
# Out:
#               0            1     2                      3          4     \
# Item_Type    Dairy  Soft Drinks  Meat  Fruits and Vegetables  Household
# Item_Weight    9.3         5.92  17.5                   19.2       8.93
#
#                      5            6            7             8     \
# Item_Type    Baking Goods  Snack Foods  Snack Foods  Frozen Foods
# Item_Weight        10.395        13.65        12.15          16.2
#
#                      9     ...  8513    8514          8515    8516  \
# Item_Type    Frozen Foods  ...  Meat  Canned  Baking Goods  Others
# Item_Weight          19.2  ...  12.0    15.0          20.7    18.6
#
#                      8517         8518          8519                8520  \
# Item_Type    Frozen Foods  Snack Foods  Baking Goods  Health and Hygiene
# Item_Weight         20.75        6.865          8.38                10.6
#
#                     8521         8522
# Item_Type    Snack Foods  Soft Drinks
# Item_Weight         7.21         14.8
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Univariate data visualization on numerical data

# %%
# for continous data we use histogram
plt.hist(data['Item_Weight'],bins=10)

plt.title('ITEM INFORMATIONRMATION')
plt.xlabel('Item weight')
plt.ylabel('#Frequency')
plt.show()

# %%
# Distplot is used for Probability density function


import seaborn as sns
sns.distplot(data['Item_MRP'],bins=10)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12748\2609726769.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Item_MRP'],bins=10)
# <AxesSubplot: xlabel='Item_MRP', ylabel='Density'>

# %%
w=data.head(100)
w
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15         9.30          Low Fat         0.016047
# 1            DRC01         5.92          Regular         0.019278
# 2            FDN15        17.50          Low Fat         0.016760
# 3            FDX07        19.20          Regular         0.000000
# 4            NCD19         8.93          Low Fat         0.000000
# ..             ...          ...              ...              ...
# 95           FDU04        12.15          Low Fat         0.009715
# 96           FDF41        12.15          Low Fat         0.131384
# 97           FDB56         8.75          Regular         0.074613
# 98           NCP18        12.15          Low Fat         0.028460
# 99           FDB56         8.75          Regular         0.074627
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0                   Dairy  249.8092            OUT049
# 1             Soft Drinks   48.2692            OUT018
# ...

# %%
import seaborn as sns

# potential outliers help to identify the noisy data

# %%
sns.boxplot(data['Item_MRP'])
sns.despine()

# %%
#  How to generate frequency table by using pandas

# %%
import pandas as pd

# %%
test=data.groupby(['Item_Type'])
test.size()
# Out:
# Item_Type
# Baking Goods              648
# Breads                    251
# Breakfast                 110
# Canned                    649
# Dairy                     682
# Frozen Foods              856
# Fruits and Vegetables    1232
# Hard Drinks               214
# Health and Hygiene        520
# Household                 910
# Meat                      425
# Others                    169
# Seafood                    64
# Snack Foods              1200
# Soft Drinks               445
# Starchy Foods             148
# dtype: int64

# %%
# How to remove duplicate data

# %%
rem_dup=data.drop_duplicates(['Outlet_Type'])
print(rem_dup)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 3           FDX07        19.20          Regular         0.000000
# 7           FDP10        12.15          Low Fat         0.127470
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 3  Fruits and Vegetables  182.0950            OUT010
# 7            Snack Foods  107.7622            OUT027
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 3                       1998      Medium               Tier 3
# 7                       1985      Medium               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# ...

# %%
test=data.groupby(['Item_Type'])
test.describe()
# Out:
#                       Item_Weight                                        \
#                             count       mean       std    min       25%
# Item_Type
# Baking Goods                648.0  12.255139  4.341096  4.880   9.10000
# Breads                      251.0  11.497311  4.013711  4.635   8.00000
# Breakfast                   110.0  12.650182  4.533440  6.425   8.26875
# Canned                      649.0  12.279314  4.179589  4.615   8.63000
# Dairy                       682.0  13.209025  4.295643  4.805  10.80000
# Frozen Foods                856.0  12.751460  4.136056  4.555   9.30000
# Fruits and Vegetables      1232.0  13.038953  4.180478  5.460  10.17125
# Hard Drinks                 214.0  11.508925  3.927453  4.610   8.37250
# Health and Hygiene          520.0  12.970567  4.119632  5.175  10.10000
# Household                   910.0  13.179852  4.587885  5.030   9.10000
# Meat                        425.0  12.679165  4.166753  5.150  10.19500
# ...

# %%
#  univariate data visualization on  categorical data

# %%
data['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
data['Outlet_Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
data['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
data['Item_Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
# piechart
data['Outlet_Type'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot: ylabel='Outlet_Type'>

# %%
data['Item_Type'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <AxesSubplot: ylabel='Item_Type'>

# %%
# Bivariate data visualization

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#Scatter plot for numerical dataa

plt.scatter(data['Item_MRP'],data['Item_Outlet_Sales'],color='g')
plt.title('item prize vs outlet sales')
plt.xlabel('Item prize')
plt.ylabel('outlet sales')
# Out:
# Text(0, 0.5, 'outlet sales')

# %%
# convert categorical data into numerical by using Ordinal Encoding

# %%
data['Outlet_Size'].unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %%
data['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
 data['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
 from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data.iloc[:,8:10],data.iloc[:,-1],test_size=0.2)

# %%
 X_train
# Out:
#      Outlet_Size Outlet_Location_Type
# 1160      Medium               Tier 3
# 1468      Medium               Tier 3
# 4091      Medium               Tier 3
# 6569        High               Tier 3
# 6383       Small               Tier 2
# ...          ...                  ...
# 2814       Small               Tier 2
# 5696      Medium               Tier 2
# 7838       Small               Tier 2
# 4888        High               Tier 3
# 1092      Medium               Tier 3
#
# [6818 rows x 2 columns]

# %%
 from sklearn.preprocessing import OrdinalEncoder

# %%
 oe=OrdinalEncoder(categories=[['Small','Medium','High'],['Tier 1','Tier 2','Tier 3']])

# %%
 oe.fit(X_train)
# Out:
# OrdinalEncoder(categories=[['Small', 'Medium', 'High'],
#                            ['Tier 1', 'Tier 2', 'Tier 3']])

# %%
 X_train=oe.transform(X_train)

# %%
 X_train
# Out:
# array([[1., 2.],
#        [1., 2.],
#        [1., 2.],
#        ...,
#        [0., 1.],
#        [2., 2.],
#        [1., 2.]])

# %%
# One hot encoding  ...Nominal encoding

# %%
 data['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
 data['Item_Type'].nunique()
# Out:
# 16

# %%
 z=pd.get_dummies(data,columns=['Item_Type','Outlet_Type'])

# %%
 z
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0              FDA15        9.300          Low Fat         0.016047  249.8092
# 1              DRC01        5.920          Regular         0.019278   48.2692
# 2              FDN15       17.500          Low Fat         0.016760  141.6180
# 3              FDX07       19.200          Regular         0.000000  182.0950
# 4              NCD19        8.930          Low Fat         0.000000   53.8614
# ...              ...          ...              ...              ...       ...
# 8518           FDF22        6.865          Low Fat         0.056783  214.5218
# 8519           FDS36        8.380          Regular         0.046982  108.1570
# 8520           NCJ29       10.600          Low Fat         0.035186   85.1224
# 8521           FDN46        7.210          Regular         0.145221  103.1332
# 8522           DRG01       14.800          Low Fat         0.044878   75.4670
#
# ...

# %%
z.drop(['Item_Identifier','Item_Weight','Item_Fat_Content','Item_Visibility','Item_MRP','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size','Outlet_Location_Type','Item_Outlet_Sales'],axis=1,inplace=True)

# %%
z
# Out:
#       Item_Type_Baking Goods  Item_Type_Breads  Item_Type_Breakfast  \
# 0                          0                 0                    0
# 1                          0                 0                    0
# 2                          0                 0                    0
# 3                          0                 0                    0
# 4                          0                 0                    0
# ...                      ...               ...                  ...
# 8518                       0                 0                    0
# 8519                       1                 0                    0
# 8520                       0                 0                    0
# 8521                       0                 0                    0
# 8522                       0                 0                    0
#
#       Item_Type_Canned  Item_Type_Dairy  Item_Type_Frozen Foods  \
# 0                    0                1                       0
# ...

# %%
# Apply regression model

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
cols = ['Item_Identifier', 'Item_Fat_Content',
       'Item_Type', 'Outlet_Identifier',
       'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
       'Outlet_Type']

# %%
#MAPPING EACH CATEGORICAL COLUMN WITH RESPECTIVE FREQUENCY OF THE VALUES IN THE COLUMNS
for i in cols:
    x  = data[i].value_counts().to_dict()
    data[i] = data[i].map(x)

# %%
data.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0                8         9.30              5089         0.016047        682
# 1                6         5.92              2889         0.019278        445
# 2                7        17.50              5089         0.016760        425
# 3                6        19.20              2889         0.000000       1232
# 4                6         8.93              5089         0.000000        910
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                930                        930         5203
# 1   48.2692                928                        928         5203
# 2  141.6180                930                        930         5203
# 3  182.0950                555                        555         5203
# 4   53.8614                932                        932          932
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %%
#REMOVING LESS CORRELATED COLUMNS 
data =data.drop(["Item_Weight","Item_Identifier", "Item_Type", "Item_Fat_Content","Outlet_Location_Type"], axis = 1)

# %%
data.head()
# Out:
#    Item_Visibility  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0         0.016047  249.8092                930                        930
# 1         0.019278   48.2692                928                        928
# 2         0.016760  141.6180                930                        930
# 3         0.000000  182.0950                555                        555
# 4         0.000000   53.8614                932                        932
#
#    Outlet_Size  Outlet_Type  Item_Outlet_Sales
# 0         5203         5577          3735.1380
# 1         5203          928           443.4228
# 2         5203         5577          2097.2700
# 3         5203         1083           732.3800
# 4          932         5577           994.7052

# %%
#Independent Variables:
x = data.drop("Item_Outlet_Sales", axis = 1) 

#Depenedent Variables 
y = data["Item_Outlet_Sales"].values.reshape(-1,1)

# %%
#Splitting The data  into Train and Test Dataset:
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x,y, test_size =0.20, random_state = 3)

# %%
# Applying Linear Regression Model
from sklearn.linear_model import LinearRegression
regressor =LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Prediction
y_pred = regressor.predict(x_test)

# %%
#Accuracy of Model (Apply R2_score)
from sklearn.metrics import r2_score, mean_squared_error
r2_score(y_test, y_pred)
# Out:
# 0.5670192213096193

# %%
#Residue of the Linear Regression Model 
residue_lr = y_test -y_pred

# %%
#Plotting Residual Plot
plt.scatter(y_test,residue_lr, c = "red")
plt.xlabel("residual")
plt.ylabel("y_test")
plt.axhline(y = 0)
